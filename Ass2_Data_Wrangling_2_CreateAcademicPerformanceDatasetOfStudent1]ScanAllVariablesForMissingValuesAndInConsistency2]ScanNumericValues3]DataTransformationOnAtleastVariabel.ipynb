# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../student_performance.csv')

# %%
df
# Out:
#     id name grade department  marks
# 0    1  AAA     A   computer   90.0
# 1    2  AAB     B         it   75.0
# 2    3  AAC     A        NaN   93.0
# 3    4  AAD     C   computer    NaN
# 4    5  AAE     A       entc   98.0
# 5    6  AAF     C         it   67.0
# 6    7  NaN     D       entc   52.0
# 7    8  AAH     B   computer   76.0
# 8    9  AAI     A   computer   90.0
# 9   10  AAJ     A   computer   90.0
# 10  11  AAK     A         it   90.0
# 11  12  AAL     C   computer   90.0
# 12  13  AAM     A   computer   90.0
# 13  14  AAN     A   computer    NaN
# 14  15  AAO     A         it   90.0
# 15  16  AAP     D        NaN   53.0
# 16  17  AAQ     B   computer   76.0
# 17  18  AAR     A         it   90.0
# 18  19  AAS     B   computer   82.0
# 19  20  AAT     B         it   74.0
# 20  21  AAU     B   computer   76.0
# 21  22  AAV     B   computer   77.0
# 22  23  AAW     A   computer   90.0
# 23  24  AAX     A       entc   90.0
# 24  25  AAY     A        NaN   90.0
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'grade', 'department', 'marks'], dtype='object')

# %%
df.isnull().sum()
# Out:
# id            0
# name          1
# grade         0
# department    3
# marks         3
# dtype: int64

# %%
df.dtypes
# Out:
# id              int64
# name           object
# grade          object
# department     object
# marks         float64
# dtype: object

# %%
# gives number of rows and columns in dataFrame
df.shape
# Out:
# (48, 5)

# %%
# gives size of dataFrame (rows*columns)
df.size
# Out:
# 240

# %%
df.isnull()
# Out:
#        id   name  grade  department  marks
# 0   False  False  False       False  False
# 1   False  False  False       False  False
# 2   False  False  False        True  False
# 3   False  False  False       False   True
# 4   False  False  False       False  False
# 5   False  False  False       False  False
# 6   False   True  False       False  False
# 7   False  False  False       False  False
# 8   False  False  False       False  False
# 9   False  False  False       False  False
# 10  False  False  False       False  False
# 11  False  False  False       False  False
# 12  False  False  False       False  False
# 13  False  False  False       False   True
# 14  False  False  False       False  False
# 15  False  False  False        True  False
# 16  False  False  False       False  False
# 17  False  False  False       False  False
# 18  False  False  False       False  False
# 19  False  False  False       False  False
# 20  False  False  False       False  False
# ...

# %%
df.isnull().sum()
# Out:
# id            0
# name          1
# grade         0
# department    3
# marks         3
# dtype: int64

# %%
df['marks'] = df['marks'].interpolate()

# %%
df
# Out:
#     id name grade department  marks
# 0    1  AAA     A   computer   90.0
# 1    2  AAB     B         it   75.0
# 2    3  AAC     A        NaN   93.0
# 3    4  AAD     C   computer   95.5
# 4    5  AAE     A       entc   98.0
# 5    6  AAF     C         it   67.0
# 6    7  NaN     D       entc   52.0
# 7    8  AAH     B   computer   76.0
# 8    9  AAI     A   computer   90.0
# 9   10  AAJ     A   computer   90.0
# 10  11  AAK     A         it   90.0
# 11  12  AAL     C   computer   90.0
# 12  13  AAM     A   computer   90.0
# 13  14  AAN     A   computer   90.0
# 14  15  AAO     A         it   90.0
# 15  16  AAP     D        NaN   53.0
# 16  17  AAQ     B   computer   76.0
# 17  18  AAR     A         it   90.0
# 18  19  AAS     B   computer   82.0
# 19  20  AAT     B         it   74.0
# 20  21  AAU     B   computer   76.0
# 21  22  AAV     B   computer   77.0
# 22  23  AAW     A   computer   90.0
# 23  24  AAX     A       entc   90.0
# 24  25  AAY     A        NaN   90.0
# ...

# %%
df.isnull().sum()
# Out:
# id            0
# name          1
# grade         0
# department    3
# marks         0
# dtype: int64

# %%
df.shape
# Out:
# (48, 5)

# %%
df['department'] = df['department'].fillna(method='bfill')

# %%
df.isnull().sum()
# Out:
# id            0
# name          1
# grade         0
# department    0
# marks         0
# dtype: int64

# %%
df['name'] = df['name'].replace(to_replace=np.nan,value='ZZZ')

# %%
df.isnull().sum()
# Out:
# id            0
# name          0
# grade         0
# department    0
# marks         0
# dtype: int64

# %%
# Check the data types and convert into appropriate types
df.dtypes
# Out:
# id              int64
# name           object
# grade          object
# department     object
# marks         float64
# dtype: object

# %%
df['marks'] = df['marks'].astype('int64')

# %%
df.dtypes
# Out:
# id             int64
# name          object
# grade         object
# department    object
# marks          int64
# dtype: object

# %%
# find the outliers
import matplotlib.pyplot as plt
columns = ['marks']
df.boxplot(columns)
# Out:
# <Axes: >

# %%
# Finding the row index with specified condition
np.where(df['marks'] < 60)
# Out:
# (array([ 6, 15, 45, 46, 47], dtype=int64),)

# %%
np.where(df['marks'] > 80)
# Out:
# (array([ 0,  2,  3,  4,  8,  9, 10, 11, 12, 13, 14, 17, 18, 22, 23, 24, 25,
#         26, 27, 31, 32, 33, 34, 37, 38, 39, 41, 42, 43, 44], dtype=int64),)

# %%
np.where(df['marks'] > 90)
# Out:
# (array([ 2,  3,  4, 37, 38], dtype=int64),)

# %%
df['marks'] > 90
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37     True
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# Name: marks, dtype: bool

# %%
df[(df['marks'] > 85) & (df['grade'] == 'A')]
# Out:
#     id name grade department  marks
# 0    1  AAA     A   computer     90
# 2    3  AAC     A   computer     93
# 4    5  AAE     A       entc     98
# 8    9  AAI     A   computer     90
# 9   10  AAJ     A   computer     90
# 10  11  AAK     A         it     90
# 12  13  AAM     A   computer     90
# 13  14  AAN     A   computer     90
# 14  15  AAO     A         it     90
# 17  18  AAR     A         it     90
# 22  23  AAW     A   computer     90
# 23  24  AAX     A       entc     90
# 24  25  AAY     A   computer     90
# 25  26  AAZ     A   computer     90
# 26  27  ABA     A       entc     90
# 27  28  ACA     A   computer     90
# 31  34  AHA     A   computer     90
# 32  35  AIA     A       entc     90
# 33  36  AJA     A         it     90
# 34  37  AKA     A         it     90
# 37  40  ANA     A   computer     91
# 38  41  AOA     A         it     92
# 39  42  APA     A   computer     90
# 41  44  ARA     A         it     90
# 42  45  ASA     A   computer     89
# ...

# %%
df[(df['department'] == 'computer')].shape
# Out:
# (26, 5)

# %%
# by using this we can remove outliers from dataframe
new_df = df[(df['marks'] > 90)]

# %%
new_df
# Out:
#     id name grade department  marks
# 2    3  AAC     A   computer     93
# 3    4  AAD     C   computer     95
# 4    5  AAE     A       entc     98
# 37  40  ANA     A   computer     91
# 38  41  AOA     A         it     92

# %%
df[(df['marks'] > 90)].shape
# Out:
# (5, 5)

# %%
entc = df[(df['department'] == 'entc')]

# %%
entc
# Out:
#     id name grade department  marks
# 4    5  AAE     A       entc     98
# 6    7  ZZZ     D       entc     52
# 23  24  AAX     A       entc     90
# 26  27  ABA     A       entc     90
# 28  29  ADA     C       entc     65
# 32  35  AIA     A       entc     90
# 45  48  AWA     D       entc     45
# 46  49  AXA     D       entc     52

# %%
d_grade = df[(df['grade'] == 'D')]

# %%
d_grade.shape
# Out:
# (6, 5)

# %%
df
# Out:
#     id name grade department  marks
# 0    1  AAA     A   computer     90
# 1    2  AAB     B         it     75
# 2    3  AAC     A   computer     93
# 3    4  AAD     C   computer     95
# 4    5  AAE     A       entc     98
# 5    6  AAF     C         it     67
# 6    7  ZZZ     D       entc     52
# 7    8  AAH     B   computer     76
# 8    9  AAI     A   computer     90
# 9   10  AAJ     A   computer     90
# 10  11  AAK     A         it     90
# 11  12  AAL     C   computer     90
# 12  13  AAM     A   computer     90
# 13  14  AAN     A   computer     90
# 14  15  AAO     A         it     90
# 15  16  AAP     D   computer     53
# 16  17  AAQ     B   computer     76
# 17  18  AAR     A         it     90
# 18  19  AAS     B   computer     82
# 19  20  AAT     B         it     74
# 20  21  AAU     B   computer     76
# 21  22  AAV     B   computer     77
# 22  23  AAW     A   computer     90
# 23  24  AAX     A       entc     90
# 24  25  AAY     A   computer     90
# ...
