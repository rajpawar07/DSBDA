# %%
class MinHeap:
    def __init__(self):
        self.heap = []
        
    def size(self):
        return len(self.heap)
        
    def heapify(self,idx):
        left = idx*2+1
        right = idx*2+2
        small = idx
        if left < self.size() and self.heap[left][0] < self.heap[idx][0]:
            small = left
            
        if right < self.size() and self.heap[right][0] < self.heap[idx][0]:
            small = right
        
        if small != idx:
            temp = self.heap[small]
            self.heap[small] = self.heap[idx]
            self.heap[idx] = temp
        
            self.heapify(small)
        
        
    def push(self,value):
        newElementIdx = len(self.heap);
        self.heap.append(value)
        
        parentIdx = int((newElementIdx-1)/2)
        # perform heap up operation
        while parentIdx >= 0 and self.heap[parentIdx][0] > self.heap[newElementIdx][0]:
            temp = self.heap[parentIdx]
            self.heap[parentIdx] = self.heap[newElementIdx]
            self.heap[newElementIdx] = temp
            newElementIdx = parent
            parent = int((newElementIdx-1)/2)
            
    def pop(self):
        if self.size() <= 0:
            return None
        
        top = self.heap[0]
        self.heap[0] = self.heap[self.size()-1]
        self.heap.pop()
        self.heapify(0)
        return top
        

if __name__ == '__main__':
    v = int(input("Enter the number of vertices : "))
    
    # create an empty graph
    graph = [[0 for i in range(v)] for j in range(v)]
    
    e = int(input("Enter the number of edges : "))
    # take edges with weight and add in graph
    for i in range(e):
        input_line = input("Enter edge %d (s, d, w):"%(i+1))
        input_line = input_line.split();
        input_line = [int(ele) for ele in input_line]
        s = input_line[0]
        d = input_line[1]
        w = input_line[2]
        graph[s][d] = w
        graph[d][s] = w
    
    dist = [1e9]*v
    minHeap = MinHeap()
    minHeap.push([0,[0]])

    dist[0] = 0
    
    while minHeap.size() > 0 :
        node = minHeap.pop()
        s = node[1][0]
        w = node[0]
        
        for adj in range(v):
            if graph[s][adj] != 0:
                if dist[adj] > (w + graph[s][adj]):
                    dist[adj] = w + graph[s][adj]
                    minHeap.push([dist[adj],[adj]])
                
    
    print(dist)
# Out:
# Enter the number of vertices : 6
# Enter the number of edges : 8
# Enter edge 1 (s, d, w):0 1 4
# Enter edge 2 (s, d, w):0 2 4
# Enter edge 3 (s, d, w):1 2 2
# Enter edge 4 (s, d, w):2 3 3
# Enter edge 5 (s, d, w):2 4 1
# Enter edge 6 (s, d, w):2 5 6
# Enter edge 7 (s, d, w):3 5 2
# Enter edge 8 (s, d, w):4 5 3
# [0, 4, 4, 7, 5, 8]
